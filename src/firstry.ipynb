# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# <------------------ download splitted TRAINING dataset ----------------->

#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_0.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_1.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_2.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_3.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_4.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_5.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_6.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_7.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_8.tar.gz
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/split-files/training_set_9.tar.gz


# <------------------ extract splitted TRAINING dataset ----------------->

#tar -xzvf /content/training_set_0.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_1.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_2.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_3.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_4.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_5.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_6.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_7.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_8.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
#tar -xzvf /content/training_set_9.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'


# <------------------ download TESTING dataset ----------------->
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/20181113_test_set.tar.gz

# <------------------ extract TESTING dataset ----------------->
#tar -xzvf /content/20181113_test_set.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'

# <------------------ get TRACK_FEATURES dataset ----------------->
#wget https://os.zhdk.cloud.switch.ch/swift/v1/crowdai-public/spotify-sequential-skip-prediction-challenge/20181120_track_features.tar.gz
#tar -xzvf /content/20181120_track_features.tar.gz -C '/content/drive/My Drive/Mineria de datos/datasets'
# <------------------ get Training MINI dataset ----------------->
#wget https://aicrowd-production.s3.eu-central-1.amazonaws.com/dataset_files/challenge_25/0654d015-d4b4-4357-8040-6a846dec093d_training_set_track_features_mini.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJ6IZH6GWKDCCDFAQ%2F20200115%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20200115T195610Z&X-Amz-Expires=604800&X-Amz-SignedHeaders=host&X-Amz-Signature=2200eac696c913f21e85d3ec94b067e6fa3ebce43fd32a43448d4dca9ac20460
#tar -xzvf /content/0654d015-d4b4-4357-8040-6a846dec093d_training_set_track_features_mini.tar.gz  -C '/content/drive/My Drive/Mineria de datos/datasets'

# %%
# !head -n 22 '/content/drive/My Drive/Mineria de datos/datasets/training_set_MINI/training_set/log_mini.csv'
# Out:
# session_id,session_position,session_length,track_id_clean,skip_1,skip_2,skip_3,not_skipped,context_switch,no_pause_before_play,short_pause_before_play,long_pause_before_play,hist_user_behavior_n_seekfwd,hist_user_behavior_n_seekback,hist_user_behavior_is_shuffle,hour_of_day,date,premium,context_type,hist_user_behavior_reason_start,hist_user_behavior_reason_end
# 0_00006f66-33e5-4de7-a324-2d18e439fc1e,1,20,t_0479f24c-27d2-46d6-a00c-7ec928f2b539,false,false,false,true,0,0,0,0,0,0,true,16,2018-07-15,true,editorial_playlist,trackdone,trackdone
# 0_00006f66-33e5-4de7-a324-2d18e439fc1e,2,20,t_9099cd7b-c238-47b7-9381-f23f2c1d1043,false,false,false,true,0,1,0,0,0,0,true,16,2018-07-15,true,editorial_playlist,trackdone,trackdone
# 0_00006f66-33e5-4de7-a324-2d18e439fc1e,3,20,t_fc5df5ba-5396-49a7-8b29-35d0d28249e0,false,false,false,true,0,1,0,0,0,0,true,16,2018-07-15,true,editorial_playlist,trackdone,trackdone
# ...
